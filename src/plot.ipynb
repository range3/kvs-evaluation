# %%
import sys
sys.path.insert(0, "..")
from pathlib import Path
import re
import json
from pprint import pprint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.collections as mc
import matplotlib.cm as cm

# %%
df = pd.read_csv('result.csv', names=('workload', 'db', 'nthreads', 'KTPS'))

# %%
df
# Out:
#           workload        db  nthreads      KTPS
# 0   workloada.spec  lock_stl         1   464.974
# 1   workloada.spec  lock_stl         2   659.064
# 2   workloada.spec  lock_stl         4   866.040
# 3   workloada.spec  lock_stl         8   928.733
# 4   workloada.spec  tbb_rand         1   280.768
# ..             ...       ...       ...       ...
# 67  workloadf.spec  tbb_rand         8  1037.430
# 68  workloadf.spec  tbb_scan         1   250.702
# 69  workloadf.spec  tbb_scan         2   479.326
# 70  workloadf.spec  tbb_scan         4   848.082
# 71  workloadf.spec  tbb_scan         8  1253.190
#
# [72 rows x 4 columns]
